# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({
    "height": [170, 180, 175],
    "weight": [65, 80, 70]
})

plt.scatter(df["height"], df["weight"])
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()
